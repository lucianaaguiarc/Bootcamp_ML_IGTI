# %%
import pandas as pd
import numpy as np
import datetime

# %%
df = pd.read_csv( 'data/bike-sharing.csv' )

# %%
df.shape
# Out:
# (17379, 17)

# %%
df.head()
# Out:
#      datetime  rec_id  season  year  month  hour  is_holiday  weekday  \
# 0  2011-01-01       1       1     0      1     0           0        6
# 1  2011-01-01       2       1     0      1     1           0        6
# 2  2011-01-01       3       1     0      1     2           0        6
# 3  2011-01-01       4       1     0      1     3           0        6
# 4  2011-01-01       5       1     0      1     4           0        6
#
#    is_workingday  weather_condition  temp   atemp  humidity  windspeed  \
# 0              0                  1  0.24  0.2879      0.81        0.0
# 1              0                  1  0.22  0.2727      0.80        0.0
# 2              0                  1  0.22  0.2727      0.80        0.0
# 3              0                  1  0.24  0.2879      0.75        0.0
# 4              0                  1  0.24  0.2879      0.75        0.0
#
#    casual  registered  total_count
# 0       3          13           16
# 1       8          32           40
# ...

# %%
df.columns
# Out:
# Index(['datetime', 'rec_id', 'season', 'year', 'month', 'hour', 'is_holiday',
#        'weekday', 'is_workingday', 'weather_condition', 'temp', 'atemp',
#        'humidity', 'windspeed', 'casual', 'registered', 'total_count'],
#       dtype='object')

# %%
df.describe()
# Out:
#            rec_id        season          year         month          hour  \
# count  17379.0000  17379.000000  17379.000000  17379.000000  17379.000000
# mean    8690.0000      2.501640      0.502561      6.537775     11.546752
# std     5017.0295      1.106918      0.500008      3.438776      6.914405
# min        1.0000      1.000000      0.000000      1.000000      0.000000
# 25%     4345.5000      2.000000      0.000000      4.000000      6.000000
# 50%     8690.0000      3.000000      1.000000      7.000000     12.000000
# 75%    13034.5000      3.000000      1.000000     10.000000     18.000000
# max    17379.0000      4.000000      1.000000     12.000000     23.000000
#
#          is_holiday       weekday  is_workingday  weather_condition  \
# count  17379.000000  17379.000000   17379.000000       17379.000000
# mean       0.028770      3.003683       0.682721           1.425283
# std        0.167165      2.005771       0.465431           0.639357
# ...

# %%
df['windspeed'].mean()
# Out:
# 0.19009760630646177

# %%
df['temp'].mean()
# Out:
# 0.4969871684216583

# %%
df.loc[df['year'] == 0]
# Out:
#         datetime  rec_id  season  year  month  hour  is_holiday  weekday  \
# 0     2011-01-01       1       1     0      1     0           0        6
# 1     2011-01-01       2       1     0      1     1           0        6
# 2     2011-01-01       3       1     0      1     2           0        6
# 3     2011-01-01       4       1     0      1     3           0        6
# 4     2011-01-01       5       1     0      1     4           0        6
# ...          ...     ...     ...   ...    ...   ...         ...      ...
# 8640  2011-12-31    8641       1     0     12    19           0        6
# 8641  2011-12-31    8642       1     0     12    20           0        6
# 8642  2011-12-31    8643       1     0     12    21           0        6
# 8643  2011-12-31    8644       1     0     12    22           0        6
# 8644  2011-12-31    8645       1     0     12    23           0        6
#
#       is_workingday  weather_condition  temp   atemp  humidity  windspeed  \
# ...

# %%
df.loc[df['year'] == 1]
# Out:
#          datetime  rec_id  season  year  month  hour  is_holiday  weekday  \
# 8645   2012-01-01    8646       1     1      1     0           0        0
# 8646   2012-01-01    8647       1     1      1     1           0        0
# 8647   2012-01-01    8648       1     1      1     2           0        0
# 8648   2012-01-01    8649       1     1      1     3           0        0
# 8649   2012-01-01    8650       1     1      1     4           0        0
# ...           ...     ...     ...   ...    ...   ...         ...      ...
# 17374  2012-12-31   17375       1     1     12    19           0        1
# 17375  2012-12-31   17376       1     1     12    20           0        1
# 17376  2012-12-31   17377       1     1     12    21           0        1
# 17377  2012-12-31   17378       1     1     12    22           0        1
# 17378  2012-12-31   17379       1     1     12    23           0        1
#
#        is_workingday  weather_condition  temp   atemp  humidity  windspeed  \
# ...

# %%
df.loc[df['year'] == 0].sum()
# Out:
# datetime             2011-01-012011-01-012011-01-012011-01-012011-0...
# rec_id                                                        37372335
# season                                                           21730
# year                                                                 0
# month                                                            56832
# hour                                                            100054
# is_holiday                                                         239
# weekday                                                          26045
# is_workingday                                                     5911
# weather_condition                                                12428
# temp                                                            4228.0
# atemp                                                        4054.5089
# humidity                                                       5562.45
# ...

# %%
df.loc[df['year'] == 1].sum()
# Out:
# datetime             2012-01-012012-01-012012-01-012012-01-012012-0...
# rec_id                                                       113651175
# season                                                           21746
# year                                                              8734
# month                                                            56788
# hour                                                            100617
# is_holiday                                                         261
# weekday                                                          26156
# is_workingday                                                     5954
# weather_condition                                                12342
# temp                                                           4409.14
# atemp                                                        4213.9866
# humidity                                                       5338.16
# ...

# %%
df.groupby(['season']).mean()
# Out:
#               rec_id      year      month       hour  is_holiday   weekday  \
# season
# 1        6302.008015  0.512494   3.119755  11.648515    0.038661  3.008722
# 2        7287.727376  0.500340   4.654117  11.512134    0.021774  2.991608
# 3        9526.588968  0.501779   7.689724  11.507562    0.021352  3.033141
# 4       11655.779301  0.495747  10.702505  11.522448    0.034026  2.979915
#
#         is_workingday  weather_condition      temp     atemp  humidity  \
# season
# 1            0.658652           1.460160  0.299147  0.298116  0.581348
# 2            0.695396           1.443638  0.544663  0.520547  0.627022
# 3            0.698621           1.330294  0.706410  0.656004  0.633167
# 4            0.676749           1.472117  0.423138  0.415738  0.667124
#
#         windspeed     casual  registered  total_count
# season
# 1        0.215107  14.290901   96.823668   111.114569
# 2        0.203410  46.160581  162.183488   208.344069
# ...

# %%
df.groupby(['hour']).mean().sort_values(by=['total_count'], ascending=False)
# Out:
#            rec_id    season      year     month  is_holiday   weekday  \
# hour
# 17    8657.647945  2.494521  0.500000  6.515068    0.028767  3.000000
# 18    8673.884615  2.495879  0.501374  6.520604    0.028846  2.995879
# 8     8661.155433  2.496561  0.500688  6.525447    0.028886  3.001376
# 16    8656.647945  2.494521  0.500000  6.515068    0.028767  3.000000
# 19    8674.884615  2.495879  0.501374  6.520604    0.028846  2.995879
# 13    8664.716049  2.496571  0.500686  6.522634    0.028807  2.998628
# 12    8653.798077  2.494505  0.500000  6.517857    0.028846  3.000000
# 15    8666.716049  2.496571  0.500686  6.522634    0.028807  2.998628
# 14    8665.716049  2.496571  0.500686  6.522634    0.028807  2.998628
# 20    8675.884615  2.495879  0.501374  6.520604    0.028846  2.995879
# 9     8662.155433  2.496561  0.500688  6.525447    0.028886  3.001376
# 7     8660.155433  2.496561  0.500688  6.525447    0.028886  3.001376
# ...

# %%
df.groupby(['weekday']).mean().sort_values(by=['total_count'], ascending=False)
# Out:
#               rec_id    season      year     month       hour  is_holiday  \
# weekday
# 4        8739.579927  2.521651  0.504249  6.590045  11.556050    0.019425
# 5        8725.739043  2.495778  0.501809  6.593888  11.527945    0.019300
# 2        8665.830004  2.529148  0.501834  6.516918  11.622095    0.009376
# 3        8703.582222  2.510707  0.503434  6.543838  11.527273    0.009697
# 6        8652.199841  2.476115  0.496815  6.553344  11.483678    0.000000
# 1        8645.734167  2.488503  0.501815  6.479225  11.556676    0.144010
# 0        8697.580735  2.490408  0.507994  6.487210  11.555156    0.000000
#
#          is_workingday  weather_condition      temp     atemp  humidity  \
# weekday
# 4             0.980575           1.402266  0.507017  0.485021  0.609628
# 5             0.980700           1.412143  0.496429  0.471828  0.613840
# 2             0.990624           1.476152  0.508569  0.487179  0.639833
# ...

# %%
df.loc[df['weekday'] == 3].groupby(['hour']).mean().sort_values(by=['total_count'], ascending=False)
# Out:
#            rec_id    season      year     month  is_holiday  weekday  \
# hour
# 17    8655.442308  2.500000  0.500000  6.509615    0.009615      3.0
# 18    8734.776699  2.514563  0.504854  6.563107    0.009709      3.0
# 8     8646.442308  2.500000  0.500000  6.509615    0.009615      3.0
# 19    8735.776699  2.514563  0.504854  6.563107    0.009709      3.0
# 7     8645.442308  2.500000  0.500000  6.509615    0.009615      3.0
# 16    8654.442308  2.500000  0.500000  6.509615    0.009615      3.0
# 20    8736.776699  2.514563  0.504854  6.563107    0.009709      3.0
# 9     8647.442308  2.500000  0.500000  6.509615    0.009615      3.0
# 21    8737.776699  2.514563  0.504854  6.563107    0.009709      3.0
# 12    8650.442308  2.500000  0.500000  6.509615    0.009615      3.0
# 13    8651.442308  2.500000  0.500000  6.509615    0.009615      3.0
# 15    8653.442308  2.500000  0.500000  6.509615    0.009615      3.0
# ...

# %%
df.loc[df['weekday'] == 6].groupby(['hour']).mean().sort_values(by=['total_count'], ascending=False)
# Out:
#            rec_id    season      year     month  is_holiday  weekday  \
# hour
# 13    8640.095238  2.476190  0.495238  6.552381         0.0      6.0
# 15    8642.095238  2.476190  0.495238  6.552381         0.0      6.0
# 14    8641.095238  2.476190  0.495238  6.552381         0.0      6.0
# 12    8639.095238  2.476190  0.495238  6.552381         0.0      6.0
# 16    8643.095238  2.476190  0.495238  6.552381         0.0      6.0
# 17    8644.095238  2.476190  0.495238  6.552381         0.0      6.0
# 11    8638.095238  2.476190  0.495238  6.552381         0.0      6.0
# 18    8674.019231  2.471154  0.500000  6.538462         0.0      6.0
# 10    8637.095238  2.476190  0.495238  6.552381         0.0      6.0
# 19    8675.019231  2.471154  0.500000  6.538462         0.0      6.0
# 9     8636.095238  2.476190  0.495238  6.552381         0.0      6.0
# 20    8676.019231  2.471154  0.500000  6.538462         0.0      6.0
# ...
